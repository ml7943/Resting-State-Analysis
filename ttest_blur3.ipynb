# %%
from scipy.stats import ttest_ind
import pandas as pd

# df = pd.read_csv('data.csv')
df = pd.read_excel('/Users/limu/Desktop/Lab_work/Laurel_Morris_Lab/FC_analysis_NewNorm/RestState_norm/VTA_mni-ROI/VTA_mni-ROI_analysis.xlsx')

df.head()
# Out:
#    subj  SUB_gender_1_F_0_M  SUB_Age  Medication_1_yes_0_no  Daw  TEPSA  \
# 0   401                   0       29                      0   10     45
# 1   402                   0       33                      0   10     34
# 2   406                   0       35                      0   10     29
# 3   408                   1       20                      0   10     33
# 4   409                   0       30                      0   10     31
#
#    TEPSC  SHAPS      amyg   antPFC2  ...      cg_3   cg_25_2     dACC2  \
# 0     36     25  0.009778 -0.015563  ...  0.019346  0.024016  0.009607
# 1     27     25  0.524516 -0.074177  ...  0.089896  0.038057  0.090122
# 2     27     27  0.102085  0.175338  ...  0.337411  0.201482  0.313849
# 3     28     42  0.092799  0.129770  ...  0.458718  0.541782  0.173754
# 4     22     38  0.310453  0.149389  ...  0.107298 -0.112332  0.389932
#
#       DCaud    dmPFC3    Hb_mni  hipp_thr  rl_accumbens    sgACC5    vmPFC2
# 0  0.028414  0.000557  0.048883  0.018453      0.032614  0.015850  0.012750
# 1  0.212527 -0.153512  0.350947  0.420406      0.379224  0.105744  0.265345
# 2  0.055079  0.183705  0.286954  0.297067      0.155296  0.320784  0.392381
# 3  0.181676  0.248491  0.243048  0.381370      0.557811  0.501136  0.409867
# 4  0.015590  0.257814  0.121761  0.288810      0.249510  0.112237  0.161506
#
# [5 rows x 22 columns]

# %%
# Review
mdd_group = df[df['subj'].astype(str).str.startswith('4')]
hc_group = df[df['subj'].astype(str).str.startswith('5')]

for column in df.columns[1:]: # skip column subj
    mdd_values = mdd_group[column]
    hc_values = hc_group[column]
    t_statistic, p_value = ttest_ind(mdd_values, hc_values)
    print(f"Variable: {column}, t-statistic: {t_statistic}, p-value: {p_value}")
# Out:
# Variable: SUB_gender_1_F_0_M, t-statistic: 0.4182669569383275, p-value: 0.6769314860995057
# Variable: SUB_Age, t-statistic: -1.1207989314836355, p-value: 0.26590260335160254
# Variable: Medication_1_yes_0_no, t-statistic: 5.78786571193471, p-value: 1.5091107727029277e-07
# Variable: Daw, t-statistic: 0.9077920364727161, p-value: 0.3668576507912079
# Variable: TEPSA, t-statistic: -5.088250971196117, p-value: 2.537505111729526e-06
# Variable: TEPSC, t-statistic: -3.0535558505249756, p-value: 0.0031165073933428346
# Variable: SHAPS, t-statistic: 6.77583988104409, p-value: 2.314895538291923e-09
# Variable: amyg, t-statistic: 1.1727478123852537, p-value: 0.24455969192486038
# Variable: antPFC2, t-statistic: 0.5603111088359203, p-value: 0.5769152422605008
# Variable: dlPFC2, t-statistic: -0.8399882207837307, p-value: 0.4035497394108496
# Variable: IFC, t-statistic: -0.1389407260545376, p-value: 0.8898645007258482
# Variable: cg_3, t-statistic: 0.8711858410579392, p-value: 0.38639636308994696
# Variable: cg_25_2, t-statistic: 1.4812441155382887, p-value: 0.14267577164498182
# Variable: dACC2, t-statistic: -0.45602815044815576, p-value: 0.6496701794050409
# Variable: DCaud, t-statistic: -0.17934760672089908, p-value: 0.8581420597970323
# Variable: dmPFC3, t-statistic: 1.1765496351116445, p-value: 0.2430473007162859
# Variable: Hb_mni, t-statistic: -0.3551684393275352, p-value: 0.7234471958418248
# Variable: hipp_thr, t-statistic: 1.0096229684554263, p-value: 0.3158796124812191
# Variable: rl_accumbens, t-statistic: 0.6591962827225588, p-value: 0.5117621887942865
# Variable: sgACC5, t-statistic: 1.090613553473933, p-value: 0.27888869168284286
# Variable: vmPFC2, t-statistic: 1.7701181927564595, p-value: 0.0807180028263679

# %%
# Group difference
import pandas as pd
from scipy.stats import ttest_ind
import statsmodels.api as sm

# Split data into MDD group and HC group
mdd_group = df[df['subj'].astype(str).str.startswith('4')]
hc_group = df[df['subj'].astype(str).str.startswith('5')]

# Perform t-test for each variable
for column in ['amyg', 'antPFC2', 'dlPFC2', 'IFC', 'cg_3', 'cg_25_2', 'dACC2', 'DCaud', 'dmPFC3', 'Hb_mni', 'hipp_thr', 'rl_accumbens', 'sgACC5', 'vmPFC2']: 
    mdd_values = mdd_group[column]
    hc_values = hc_group[column]
    
    # Add covariates
    X = sm.add_constant(df[['SUB_gender_1_F_0_M', 'SUB_Age', 'Medication_1_yes_0_no', 'Daw']])
    model = sm.OLS(df[column], X).fit()
    
    t_statistic = model.tvalues['SUB_gender_1_F_0_M']
    p_value = model.pvalues['SUB_gender_1_F_0_M']
    
    print(f"Variable: {column}, t-statistic: {t_statistic}, p-value: {p_value}")
# Out:
# Variable: amyg, t-statistic: -0.24377342817436778, p-value: 0.8080900865062866
# Variable: antPFC2, t-statistic: 0.21362953884280364, p-value: 0.8314314984379928
# Variable: dlPFC2, t-statistic: -0.25524298589774547, p-value: 0.799253195221042
# Variable: IFC, t-statistic: -1.2658179208934823, p-value: 0.20960322344822568
# Variable: cg_3, t-statistic: 2.450580681087533, p-value: 0.016658859197538067
# Variable: cg_25_2, t-statistic: 1.4696976158063921, p-value: 0.14594048526613246
# Variable: dACC2, t-statistic: -0.05298076450228229, p-value: 0.957891952662074
# Variable: DCaud, t-statistic: -0.18248979520808495, p-value: 0.8557042068623439
# Variable: dmPFC3, t-statistic: 0.608893709890386, p-value: 0.5444851267395161
# Variable: Hb_mni, t-statistic: 0.17749457799452392, p-value: 0.8596115089269085
# Variable: hipp_thr, t-statistic: -0.03996744716979555, p-value: 0.9682281858264525
# Variable: rl_accumbens, t-statistic: 0.4219424549953993, p-value: 0.6743070596560541
# Variable: sgACC5, t-statistic: 2.122795347603154, p-value: 0.03716248909122287
# Variable: vmPFC2, t-statistic: 0.2178904928692817, p-value: 0.8281223564796216

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats import pearsonr

# Calculate correlations between TEPSA and other variables
corr_variables = ['amyg', 'antPFC2', 'dlPFC2', 'IFC', 'cg_3', 'cg_25_2', 'dACC2', 'DCaud', 'dmPFC3', 'Hb_mni', 'hipp_thr', 'rl_accumbens', 'sgACC5', 'vmPFC2']
correlation_results = {}

for var in corr_variables:
    r, p_value = pearsonr(df['TEPSA'], df[var])
    correlation_results[var] = {'correlation_coefficient': r, 'p_value': p_value}

# Perform partial correlation analysis controlling for covariates
partial_corr_results = {}

for var in corr_variables:
    covariates = ['SUB_gender_1_F_0_M', 'SUB_Age', 'Medication_1_yes_0_no', 'Daw']
    X = sm.add_constant(df[[var] + covariates])
    partial_corr_model = sm.OLS(df['TEPSA'], X).fit()
    partial_corr_results[var] = {'coefficient': partial_corr_model.params[var],
                                 'p_value': partial_corr_model.pvalues[var],
                                 'effect_size': partial_corr_model.rsquared}

# Print the results
for var in corr_variables:
    print(f"Correlation between TEPSA and {var}:")
    print(f"Pearson correlation coefficient: {correlation_results[var]['correlation_coefficient']}")
    print(f"Pearson correlation p-value: {correlation_results[var]['p_value']}")
    print(f"Partial correlation coefficient: {partial_corr_results[var]['coefficient']}")
    print(f"Partial correlation p-value: {partial_corr_results[var]['p_value']}")
    print(f"Partial correlation effect size (R-squared): {partial_corr_results[var]['effect_size']}")
    print("\n")
# Out:
# Correlation between TEPSA and amyg:
# Pearson correlation coefficient: -0.23213826962427492
# Pearson correlation p-value: 0.04084328851719636
# Partial correlation coefficient: -18.38887873534881
# Partial correlation p-value: 0.013369430444768338
# Partial correlation effect size (R-squared): 0.21560031493842513
#
#
# Correlation between TEPSA and antPFC2:
# Pearson correlation coefficient: -0.08084129969699484
# Pearson correlation p-value: 0.48168394819405735
# Partial correlation coefficient: -10.4776379276279
# Partial correlation p-value: 0.45142171947000165
# Partial correlation effect size (R-squared): 0.1522637267805501
#
#
# Correlation between TEPSA and dlPFC2:
# Pearson correlation coefficient: 0.09641147427590174
# Pearson correlation p-value: 0.4010797933718232
# Partial correlation coefficient: 11.406442490727866
# Partial correlation p-value: 0.3508657021857827
# Partial correlation effect size (R-squared): 0.1558513822504285
#
#
# Correlation between TEPSA and IFC:
# Pearson correlation coefficient: -0.22043626058641674
# Pearson correlation p-value: 0.052460411672768915
# Partial correlation coefficient: -25.681754378638963
# Partial correlation p-value: 0.06573713627560948
# Partial correlation effect size (R-squared): 0.1850383537303456
#
#
# Correlation between TEPSA and cg_3:
# Pearson correlation coefficient: -0.15837260369987236
# Pearson correlation p-value: 0.16608787552983942
# Partial correlation coefficient: -16.455481724129655
# Partial correlation p-value: 0.03843272435155927
# Partial correlation effect size (R-squared): 0.1952245495108147
#
#
# Correlation between TEPSA and cg_25_2:
# Pearson correlation coefficient: -0.1947477309575129
# Pearson correlation p-value: 0.08752557519540785
# Partial correlation coefficient: -18.649962941144846
# Partial correlation p-value: 0.03409825517873614
# Partial correlation effect size (R-squared): 0.19751723201948623
#
#
# Correlation between TEPSA and dACC2:
# Pearson correlation coefficient: -0.08727700544892092
# Pearson correlation p-value: 0.4473643394332738
# Partial correlation coefficient: -8.229815090554112
# Partial correlation p-value: 0.3359588526908339
# Partial correlation effect size (R-squared): 0.15650597232047714
#
#
# Correlation between TEPSA and DCaud:
# Pearson correlation coefficient: -0.07174577253714023
# Pearson correlation p-value: 0.5324854048099202
# Partial correlation coefficient: -6.320886914854288
# Partial correlation p-value: 0.42212470196733554
# Partial correlation effect size (R-squared): 0.15317985480235485
#
#
# Correlation between TEPSA and dmPFC3:
# Pearson correlation coefficient: -0.2922014134940421
# Pearson correlation p-value: 0.009434147603512917
# Partial correlation coefficient: -32.896310147121234
# Partial correlation p-value: 0.0037979222345048153
# Partial correlation effect size (R-squared): 0.23998610249862828
#
#
# Correlation between TEPSA and Hb_mni:
# Pearson correlation coefficient: -0.04548088602865509
# Pearson correlation p-value: 0.6925507210836944
# Partial correlation coefficient: -3.2624746000417657
# Partial correlation p-value: 0.5476980493427903
# Partial correlation effect size (R-squared): 0.14982234350750356
#
#
# Correlation between TEPSA and hipp_thr:
# Pearson correlation coefficient: -0.28446791345342065
# Pearson correlation p-value: 0.011597083937573745
# Partial correlation coefficient: -20.76050368492602
# Partial correlation p-value: 0.004422917555242372
# Partial correlation effect size (R-squared): 0.23704167923925834
#
#
# Correlation between TEPSA and rl_accumbens:
# Pearson correlation coefficient: -0.08465683810716625
# Pearson correlation p-value: 0.4611697044504458
# Partial correlation coefficient: -6.612692369910253
# Partial correlation p-value: 0.3361458976304854
# Partial correlation effect size (R-squared): 0.15649752099596947
#
#
# Correlation between TEPSA and sgACC5:
# Pearson correlation coefficient: -0.13746550407318278
# Pearson correlation p-value: 0.23007384403110198
# Partial correlation coefficient: -18.71918004617003
# Partial correlation p-value: 0.07224616510677034
# Partial correlation effect size (R-squared): 0.1832682280393475
#
#
# Correlation between TEPSA and vmPFC2:
# Pearson correlation coefficient: -0.2553780226868321
# Pearson correlation p-value: 0.024034214743454213
# Partial correlation coefficient: -18.78303388499422
# Partial correlation p-value: 0.024866234529814235
# Partial correlation effect size (R-squared): 0.2035924465687141

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats import pearsonr

# Calculate correlations between TEPSC and other variables
corr_variables = ['amyg', 'antPFC2', 'dlPFC2', 'IFC', 'cg_3', 'cg_25_2', 'dACC2', 'DCaud', 'dmPFC3', 'Hb_mni', 'hipp_thr', 'rl_accumbens', 'sgACC5', 'vmPFC2']
correlation_results = {}

for var in corr_variables:
    r, p_value = pearsonr(df['TEPSC'], df[var])
    correlation_results[var] = {'correlation_coefficient': r, 'p_value': p_value}

# Perform partial correlation analysis controlling for covariates
partial_corr_results = {}

for var in corr_variables:
    covariates = ['SUB_gender_1_F_0_M', 'SUB_Age', 'Medication_1_yes_0_no', 'Daw']
    X = sm.add_constant(df[[var] + covariates])
    partial_corr_model = sm.OLS(df['TEPSC'], X).fit()
    partial_corr_results[var] = {'coefficient': partial_corr_model.params[var],
                                 'p_value': partial_corr_model.pvalues[var],
                                 'effect_size': partial_corr_model.rsquared}

# Print the results
for var in corr_variables:
    print(f"Correlation between TEPSC and {var}:")
    print(f"Pearson correlation coefficient: {correlation_results[var]['correlation_coefficient']}")
    print(f"Pearson correlation p-value: {correlation_results[var]['p_value']}")
    print(f"Partial correlation coefficient: {partial_corr_results[var]['coefficient']}")
    print(f"Partial correlation p-value: {partial_corr_results[var]['p_value']}")
    print(f"Partial correlation effect size (R-squared): {partial_corr_results[var]['effect_size']}")
    print("\n")
# Out:
# Correlation between TEPSC and amyg:
# Pearson correlation coefficient: -0.23024481551470571
# Pearson correlation p-value: 0.042563208863140856
# Partial correlation coefficient: -15.17530753537744
# Partial correlation p-value: 0.01732345721440685
# Partial correlation effect size (R-squared): 0.16376522736606425
#
#
# Correlation between TEPSC and antPFC2:
# Pearson correlation coefficient: -0.16187113718535778
# Pearson correlation p-value: 0.15680985817134596
# Partial correlation coefficient: -17.58425816487096
# Partial correlation p-value: 0.13780584746169666
# Partial correlation effect size (R-squared): 0.12229468555857903
#
#
# Correlation between TEPSC and dlPFC2:
# Pearson correlation coefficient: -0.021065828445565517
# Pearson correlation p-value: 0.8547471155219849
# Partial correlation coefficient: -2.0150044788153005
# Partial correlation p-value: 0.8478543920948015
# Partial correlation effect size (R-squared): 0.09530663411003026
#
#
# Correlation between TEPSC and IFC:
# Pearson correlation coefficient: -0.239421538565799
# Pearson correlation p-value: 0.03475643763860242
# Partial correlation coefficient: -24.821797780920022
# Partial correlation p-value: 0.03720671647449232
# Partial correlation effect size (R-squared): 0.14815697698791153
#
#
# Correlation between TEPSC and cg_3:
# Pearson correlation coefficient: -0.17062431686544635
# Pearson correlation p-value: 0.1352907317156899
# Partial correlation coefficient: -14.17217475773429
# Partial correlation p-value: 0.03733800212079724
# Partial correlation effect size (R-squared): 0.1480855360598755
#
#
# Correlation between TEPSC and cg_25_2:
# Pearson correlation coefficient: -0.10977164579739875
# Pearson correlation p-value: 0.3387086885427772
# Partial correlation coefficient: -9.915942195971148
# Partial correlation p-value: 0.19269218678100214
# Partial correlation effect size (R-squared): 0.11606924995493562
#
#
# Correlation between TEPSC and dACC2:
# Pearson correlation coefficient: -0.12417683456391652
# Pearson correlation p-value: 0.27872288859146455
# Partial correlation coefficient: -9.024508328070503
# Partial correlation p-value: 0.21703532114853957
# Partial correlation effect size (R-squared): 0.11392745087639333
#
#
# Correlation between TEPSC and DCaud:
# Pearson correlation coefficient: -0.11908185407457515
# Pearson correlation p-value: 0.2990731221934141
# Partial correlation coefficient: -7.509964137165216
# Partial correlation p-value: 0.2644672554335457
# Partial correlation effect size (R-squared): 0.11046772529595672
#
#
# Correlation between TEPSC and dmPFC3:
# Pearson correlation coefficient: -0.28610659545967965
# Pearson correlation p-value: 0.011105827821418182
# Partial correlation coefficient: -26.39038287593146
# Partial correlation p-value: 0.006912452684849068
# Partial correlation effect size (R-squared): 0.18263695028789817
#
#
# Correlation between TEPSC and Hb_mni:
# Pearson correlation coefficient: -0.005570737387227008
# Pearson correlation p-value: 0.961393112906523
# Partial correlation coefficient: -1.197678077861796
# Partial correlation p-value: 0.7968512134585981
# Partial correlation effect size (R-squared): 0.0956792849661563
#
#
# Correlation between TEPSC and hipp_thr:
# Pearson correlation coefficient: -0.18881465012619078
# Pearson correlation p-value: 0.09780874294406924
# Partial correlation coefficient: -11.818951964421078
# Partial correlation p-value: 0.06262146758890788
# Partial correlation effect size (R-squared): 0.13767685271971108
#
#
# Correlation between TEPSC and rl_accumbens:
# Pearson correlation coefficient: -0.1269684153950835
# Pearson correlation p-value: 0.26797386475025864
# Partial correlation coefficient: -8.061665522887326
# Partial correlation p-value: 0.1695572893470761
# Partial correlation effect size (R-squared): 0.11841417454154446
#
#
# Correlation between TEPSC and sgACC5:
# Pearson correlation coefficient: -0.14950920362019315
# Pearson correlation p-value: 0.1913934997734234
# Partial correlation coefficient: -16.468141557981163
# Partial correlation p-value: 0.06466907525603989
# Partial correlation effect size (R-squared): 0.13703554919758043
#
#
# Correlation between TEPSC and vmPFC2:
# Pearson correlation coefficient: -0.22855266148569356
# Pearson correlation p-value: 0.044150666136077724
# Partial correlation coefficient: -15.459108669475757
# Partial correlation p-value: 0.03132886529804484
# Partial correlation effect size (R-squared): 0.15165125666043056

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats import pearsonr

# Calculate correlations between SHAPS and other variables
corr_variables = ['amyg', 'antPFC2', 'dlPFC2', 'IFC', 'cg_3', 'cg_25_2', 'dACC2', 'DCaud', 'dmPFC3', 'Hb_mni', 'hipp_thr', 'rl_accumbens', 'sgACC5', 'vmPFC2']
correlation_results = {}

for var in corr_variables:
    r, p_value = pearsonr(df['SHAPS'], df[var])
    correlation_results[var] = {'correlation_coefficient': r, 'p_value': p_value}

# Perform partial correlation analysis controlling for covariates
partial_corr_results = {}

for var in corr_variables:
    covariates = ['SUB_gender_1_F_0_M', 'SUB_Age', 'Medication_1_yes_0_no', 'Daw']
    X = sm.add_constant(df[[var] + covariates])
    partial_corr_model = sm.OLS(df['SHAPS'], X).fit()
    partial_corr_results[var] = {'coefficient': partial_corr_model.params[var],
                                 'p_value': partial_corr_model.pvalues[var],
                                 'effect_size': partial_corr_model.rsquared}

# Print the results
for var in corr_variables:
    print(f"Correlation between SHAPS and {var}:")
    print(f"Pearson correlation coefficient: {correlation_results[var]['correlation_coefficient']}")
    print(f"Pearson correlation p-value: {correlation_results[var]['p_value']}")
    print(f"Partial correlation coefficient: {partial_corr_results[var]['coefficient']}")
    print(f"Partial correlation p-value: {partial_corr_results[var]['p_value']}")
    print(f"Partial correlation effect size (R-squared): {partial_corr_results[var]['effect_size']}")
    print("\n")
# Out:
# Correlation between SHAPS and amyg:
# Pearson correlation coefficient: 0.30604315372154856
# Pearson correlation p-value: 0.006430614900586667
# Partial correlation coefficient: 20.749318952223717
# Partial correlation p-value: 0.0024434151426262585
# Partial correlation effect size (R-squared): 0.2643519576265819
#
#
# Correlation between SHAPS and antPFC2:
# Pearson correlation coefficient: -0.002469646454258628
# Pearson correlation p-value: 0.9828793434063514
# Partial correlation coefficient: -0.7368102268879415
# Partial correlation p-value: 0.9547245083485274
# Partial correlation effect size (R-squared): 0.16358877042886333
#
#
# Correlation between SHAPS and dlPFC2:
# Pearson correlation coefficient: -0.10734035228456876
# Pearson correlation p-value: 0.34957964050344226
# Partial correlation coefficient: -12.532803222075945
# Partial correlation p-value: 0.27026437192537556
# Partial correlation effect size (R-squared): 0.1776489337963152
#
#
# Correlation between SHAPS and IFC:
# Pearson correlation coefficient: 0.14837185066855718
# Pearson correlation p-value: 0.19483177515183137
# Partial correlation coefficient: 14.011786299812314
# Partial correlation p-value: 0.2845499048947529
# Partial correlation effect size (R-squared): 0.17684146492631614
#
#
# Correlation between SHAPS and cg_3:
# Pearson correlation coefficient: 0.11349077756703445
# Pearson correlation p-value: 0.32249592558785056
# Partial correlation coefficient: 10.764609488422213
# Partial correlation p-value: 0.14882156092448875
# Partial correlation effect size (R-squared): 0.18758134172999896
#
#
# Correlation between SHAPS and cg_25_2:
# Pearson correlation coefficient: 0.16202978674124036
# Pearson correlation p-value: 0.15639844571335138
# Partial correlation coefficient: 13.283331263061973
# Partial correlation p-value: 0.10727182562185028
# Partial correlation effect size (R-squared): 0.19335153501970337
#
#
# Correlation between SHAPS and dACC2:
# Pearson correlation coefficient: -0.1251979839235928
# Pearson correlation p-value: 0.27475807212220055
# Partial correlation coefficient: -8.325947758382593
# Partial correlation p-value: 0.29542370846256544
# Partial correlation effect size (R-squared): 0.17625998948478505
#
#
# Correlation between SHAPS and DCaud:
# Pearson correlation coefficient: -0.08796677695181603
# Pearson correlation p-value: 0.4437686949689813
# Partial correlation coefficient: -4.287910406827943
# Partial correlation p-value: 0.5589770906770912
# Partial correlation effect size (R-squared): 0.16753624538776357
#
#
# Correlation between SHAPS and dmPFC3:
# Pearson correlation coefficient: 0.13636930503184022
# Pearson correlation p-value: 0.23384709302485182
# Partial correlation coefficient: 15.322413781397366
# Partial correlation p-value: 0.15656754846446597
# Partial correlation effect size (R-squared): 0.18670351357509563
#
#
# Correlation between SHAPS and Hb_mni:
# Pearson correlation coefficient: -0.06055158709422606
# Pearson correlation p-value: 0.5984528231897441
# Partial correlation coefficient: -2.842167330346463
# Partial correlation p-value: 0.5737411841431432
# Partial correlation effect size (R-squared): 0.16724494969135906
#
#
# Correlation between SHAPS and hipp_thr:
# Pearson correlation coefficient: 0.2455719571440032
# Pearson correlation p-value: 0.03022576781430327
# Partial correlation coefficient: 16.14728824722003
# Partial correlation p-value: 0.01840244148978181
# Partial correlation effect size (R-squared): 0.22609847062285982
#
#
# Correlation between SHAPS and rl_accumbens:
# Pearson correlation coefficient: 0.0022008986321950565
# Pearson correlation p-value: 0.9847421832716005
# Partial correlation coefficient: 0.28942454027121123
# Partial correlation p-value: 0.9640469647343785
# Partial correlation effect size (R-squared): 0.16357483159844788
#
#
# Correlation between SHAPS and sgACC5:
# Pearson correlation coefficient: 0.08638631028280486
# Pearson correlation p-value: 0.4520312837104268
# Partial correlation coefficient: 10.75498428676568
# Partial correlation p-value: 0.27060154799385555
# Partial correlation effect size (R-squared): 0.17762927179814358
#
#
# Correlation between SHAPS and vmPFC2:
# Pearson correlation coefficient: 0.07219530636734406
# Pearson correlation p-value: 0.5299136403052309
# Partial correlation coefficient: 1.9694533665656082
# Partial correlation p-value: 0.8038534902530033
# Partial correlation effect size (R-squared): 0.16427235215505986

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats import pearsonr

# Split data into MDD group and HC group
mdd_group = df[df['subj'].astype(str).str.startswith('4')]
hc_group = df[df['subj'].astype(str).str.startswith('5')]

# Calculate correlations between TEPSA and other variables for MDD group
corr_variables = ['amyg', 'antPFC2', 'dlPFC2', 'IFC', 'cg_3', 'cg_25_2', 'dACC2', 'DCaud', 'dmPFC3', 'Hb_mni', 'hipp_thr', 'rl_accumbens', 'sgACC5', 'vmPFC2']
correlation_results_mdd = {}

for var in corr_variables:
    r, p_value = pearsonr(mdd_group['TEPSA'], mdd_group[var])
    correlation_results_mdd[var] = {'correlation_coefficient': r, 'p_value': p_value}

# Calculate correlations between TEPSA and other variables for HC group
correlation_results_hc = {}

for var in corr_variables:
    r, p_value = pearsonr(hc_group['TEPSA'], hc_group[var])
    correlation_results_hc[var] = {'correlation_coefficient': r, 'p_value': p_value}

# Perform partial correlation analysis controlling for covariates for MDD group
partial_corr_results_mdd = {}

for var in corr_variables:
    covariates = ['SUB_gender_1_F_0_M', 'SUB_Age', 'Medication_1_yes_0_no', 'Daw']
    X = sm.add_constant(mdd_group[[var] + covariates])
    partial_corr_model = sm.OLS(mdd_group['TEPSA'], X).fit()
    partial_corr_results_mdd[var] = {'coefficient': partial_corr_model.params[var],
                                     'p_value': partial_corr_model.pvalues[var],
                                     'effect_size': partial_corr_model.rsquared}

# Perform partial correlation analysis controlling for covariates for HC group
partial_corr_results_hc = {}

for var in corr_variables:
    covariates = ['SUB_gender_1_F_0_M', 'SUB_Age', 'Medication_1_yes_0_no', 'Daw']
    X = sm.add_constant(hc_group[[var] + covariates])
    partial_corr_model = sm.OLS(hc_group['TEPSA'], X).fit()
    partial_corr_results_hc[var] = {'coefficient': partial_corr_model.params[var],
                                     'p_value': partial_corr_model.pvalues[var],
                                     'effect_size': partial_corr_model.rsquared}

# Print the results for MDD group
for var in corr_variables:
    print(f"MDD Group: Correlation between TEPSA and {var}:")
    print(f"Pearson correlation coefficient: {correlation_results_mdd[var]['correlation_coefficient']}")
    print(f"Pearson correlation p-value: {correlation_results_mdd[var]['p_value']}")
    print(f"Partial correlation coefficient: {partial_corr_results_mdd[var]['coefficient']}")
    print(f"Partial correlation p-value: {partial_corr_results_mdd[var]['p_value']}")
    print(f"Partial correlation effect size (R-squared): {partial_corr_results_mdd[var]['effect_size']}")
    print("\n")

# Print the results for HC group
for var in corr_variables:
    print(f"HC Group: Correlation between TEPSA and {var}:")
    print(f"Pearson correlation coefficient: {correlation_results_hc[var]['correlation_coefficient']}")
    print(f"Pearson correlation p-value: {correlation_results_hc[var]['p_value']}")
    print(f"Partial correlation coefficient: {partial_corr_results_hc[var]['coefficient']}")
    print(f"Partial correlation p-value: {partial_corr_results_hc[var]['p_value']}")
    print(f"Partial correlation effect size (R-squared): {partial_corr_results_hc[var]['effect_size']}")
    print("\n")
# Out:
# MDD Group: Correlation between TEPSA and amyg:
# Pearson correlation coefficient: -0.28928284880591887
# Pearson correlation p-value: 0.07021841040814021
# Partial correlation coefficient: -18.08794953773669
# Partial correlation p-value: 0.09341755321919261
# Partial correlation effect size (R-squared): 0.09126921517501918
#
#
# MDD Group: Correlation between TEPSA and antPFC2:
# Pearson correlation coefficient: -0.05542578162523788
# Pearson correlation p-value: 0.734090758274715
# Partial correlation coefficient: -10.431925622539065
# Partial correlation p-value: 0.6296034978455823
# Partial correlation effect size (R-squared): 0.018479915942702596
#
#
# MDD Group: Correlation between TEPSA and dlPFC2:
# Pearson correlation coefficient: 0.12502579920370993
# Pearson correlation p-value: 0.44208213767914256
# Partial correlation coefficient: 12.215339164617806
# Partial correlation p-value: 0.43979406648646135
# Partial correlation effect size (R-squared): 0.02909195878978732
#
#
# MDD Group: Correlation between TEPSA and IFC:
# Pearson correlation coefficient: -0.2051059371635468
# Pearson correlation p-value: 0.20422060927182456
# Partial correlation coefficient: -20.19458428285322
# Partial correlation p-value: 0.27572534801047777
# Partial correlation effect size (R-squared): 0.04607358665597738
#
#
# MDD Group: Correlation between TEPSA and cg_3:
# Pearson correlation coefficient: -0.16508714440078073
# Pearson correlation p-value: 0.30867765459679725
# Partial correlation coefficient: -15.071814302872399
# Partial correlation p-value: 0.19224401725064216
# Partial correlation effect size (R-squared): 0.060547330747972805
#
#
# MDD Group: Correlation between TEPSA and cg_25_2:
# Pearson correlation coefficient: -0.10842391723165065
# Pearson correlation p-value: 0.5054392274812385
# Partial correlation coefficient: -10.360737881171072
# Partial correlation p-value: 0.3927560964458794
# Partial correlation effect size (R-squared): 0.03295487637574335
#
#
# MDD Group: Correlation between TEPSA and dACC2:
# Pearson correlation coefficient: -0.0687549534276296
# Pearson correlation p-value: 0.6733497976535843
# Partial correlation coefficient: -7.22603881669813
# Partial correlation p-value: 0.6244367018609596
# Partial correlation effect size (R-squared): 0.018687364861266098
#
#
# MDD Group: Correlation between TEPSA and DCaud:
# Pearson correlation coefficient: -0.06247522386961007
# Pearson correlation p-value: 0.7017397802999414
# Partial correlation coefficient: -5.949177415589084
# Partial correlation p-value: 0.6379456059305226
# Partial correlation effect size (R-squared): 0.01815293228002457
#
#
# MDD Group: Correlation between TEPSA and dmPFC3:
# Pearson correlation coefficient: -0.229159457431353
# Pearson correlation p-value: 0.15491543141865974
# Partial correlation coefficient: -25.53784437109579
# Partial correlation p-value: 0.1085738078630435
# Partial correlation effect size (R-squared): 0.08474809002416306
#
#
# MDD Group: Correlation between TEPSA and Hb_mni:
# Pearson correlation coefficient: -0.12185433904091693
# Pearson correlation p-value: 0.45383648521589537
# Partial correlation coefficient: -8.60768709259614
# Partial correlation p-value: 0.3750378970169078
# Partial correlation effect size (R-squared): 0.03458455932088955
#
#
# MDD Group: Correlation between TEPSA and hipp_thr:
# Pearson correlation coefficient: -0.279891649720793
# Pearson correlation p-value: 0.08025499393821237
# Partial correlation coefficient: -15.297949452131881
# Partial correlation p-value: 0.10629424849208292
# Partial correlation effect size (R-squared): 0.08566565723379793
#
#
# MDD Group: Correlation between TEPSA and rl_accumbens:
# Pearson correlation coefficient: 0.026962405571316767
# Pearson correlation p-value: 0.8688276801916929
# Partial correlation coefficient: -0.12927878543482052
# Partial correlation p-value: 0.9914685645427357
# Partial correlation effect size (R-squared): 0.01164546028494906
#
#
# MDD Group: Correlation between TEPSA and sgACC5:
# Pearson correlation coefficient: -0.06671182806933033
# Pearson correlation p-value: 0.6825399110389079
# Partial correlation coefficient: -10.22812470234479
# Partial correlation p-value: 0.5030424354530335
# Partial correlation effect size (R-squared): 0.024784777763646737
#
#
# MDD Group: Correlation between TEPSA and vmPFC2:
# Pearson correlation coefficient: -0.24431353590212612
# Pearson correlation p-value: 0.12868557160081023
# Partial correlation coefficient: -21.988318898071192
# Partial correlation p-value: 0.08952328960849791
# Partial correlation effect size (R-squared): 0.09312355195288868
#
#
# HC Group: Correlation between TEPSA and amyg:
# Pearson correlation coefficient: -0.06562621884535816
# Pearson correlation p-value: 0.6954604203322877
# Partial correlation coefficient: -9.701695364978761
# Partial correlation p-value: 0.32441109343090524
# Partial correlation effect size (R-squared): 0.14654903485283155
#
#
# HC Group: Correlation between TEPSA and antPFC2:
# Pearson correlation coefficient: -0.05792697513296184
# Pearson correlation p-value: 0.729757859000889
# Partial correlation coefficient: -9.686277063830309
# Partial correlation p-value: 0.5590037430450501
# Partial correlation effect size (R-squared): 0.1298561328835347
#
#
# HC Group: Correlation between TEPSA and dlPFC2:
# Pearson correlation coefficient: -0.06011914704100395
# Pearson correlation p-value: 0.7199362533266618
# Partial correlation coefficient: -9.310336621204296
# Partial correlation p-value: 0.606635826786883
# Partial correlation effect size (R-squared): 0.1278104118933735
#
#
# HC Group: Correlation between TEPSA and IFC:
# Pearson correlation coefficient: -0.36576171865955254
# Pearson correlation p-value: 0.023928435838339694
# Partial correlation coefficient: -52.14117475008348
# Partial correlation p-value: 0.0067666937965440025
# Partial correlation effect size (R-squared): 0.2982362175864911
#
#
# HC Group: Correlation between TEPSA and cg_3:
# Pearson correlation coefficient: -0.0729466713758764
# Pearson correlation p-value: 0.6633934900426112
# Partial correlation coefficient: -5.612373543811188
# Partial correlation p-value: 0.5852534164693939
# Partial correlation effect size (R-squared): 0.1286878145279179
#
#
# HC Group: Correlation between TEPSA and cg_25_2:
# Pearson correlation coefficient: -0.16527475967423003
# Pearson correlation p-value: 0.3213783558843526
# Partial correlation coefficient: -14.225332386412605
# Partial correlation p-value: 0.2643805047184731
# Partial correlation effect size (R-squared): 0.15372802295290822
#
#
# HC Group: Correlation between TEPSA and dACC2:
# Pearson correlation coefficient: -0.1942322281335206
# Pearson correlation p-value: 0.24260511224938938
# Partial correlation coefficient: -12.177625198935436
# Partial correlation p-value: 0.1769946775019561
# Partial correlation effect size (R-squared): 0.1686166488613271
#
#
# HC Group: Correlation between TEPSA and DCaud:
# Pearson correlation coefficient: -0.13138854906997915
# Pearson correlation p-value: 0.43169461024760747
# Partial correlation coefficient: -4.68061083600119
# Partial correlation p-value: 0.5973873864897188
# Partial correlation effect size (R-squared): 0.12818200522874468
#
#
# HC Group: Correlation between TEPSA and dmPFC3:
# Pearson correlation coefficient: -0.3130207467992978
# Pearson correlation p-value: 0.055680345727428415
# Partial correlation coefficient: -34.74791613464152
# Partial correlation p-value: 0.025707305626465816
# Partial correlation effect size (R-squared): 0.24545452713365223
#
#
# HC Group: Correlation between TEPSA and Hb_mni:
# Pearson correlation coefficient: -0.040888041238797114
# Pearson correlation p-value: 0.8074377242576212
# Partial correlation coefficient: -1.5579544620135781
# Partial correlation p-value: 0.7828217811609359
# Partial correlation effect size (R-squared): 0.12272085479955774
#
#
# HC Group: Correlation between TEPSA and hipp_thr:
# Pearson correlation coefficient: -0.24044368872938818
# Pearson correlation p-value: 0.14591520863119423
# Partial correlation coefficient: -22.96893851776712
# Partial correlation p-value: 0.03959246362710914
# Partial correlation effect size (R-squared): 0.22807753120545304
#
#
# HC Group: Correlation between TEPSA and rl_accumbens:
# Pearson correlation coefficient: -0.13792808871873027
# Pearson correlation p-value: 0.40891699258660674
# Partial correlation coefficient: -5.732414039170546
# Partial correlation p-value: 0.4425436824043265
# Partial correlation effect size (R-squared): 0.13647624022279103
#
#
# HC Group: Correlation between TEPSA and sgACC5:
# Pearson correlation coefficient: -0.11733552597239406
# Pearson correlation p-value: 0.4829461591219696
# Partial correlation coefficient: -10.70736095343598
# Partial correlation p-value: 0.4359438083632152
# Partial correlation effect size (R-squared): 0.13693458782642942
#
#
# HC Group: Correlation between TEPSA and vmPFC2:
# Pearson correlation coefficient: -0.11184819316959954
# Pearson correlation p-value: 0.5037831836569999
# Partial correlation coefficient: -7.869909591321431
# Partial correlation p-value: 0.4434670432644504
# Partial correlation effect size (R-squared): 0.13641293306061442

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats import pearsonr

# Split data into MDD group and HC group
mdd_group = df[df['subj'].astype(str).str.startswith('4')]
hc_group = df[df['subj'].astype(str).str.startswith('5')]

# Calculate correlations between TEPSC and other variables for MDD group
corr_variables = ['amyg', 'antPFC2', 'dlPFC2', 'IFC', 'cg_3', 'cg_25_2', 'dACC2', 'DCaud', 'dmPFC3', 'Hb_mni', 'hipp_thr', 'rl_accumbens', 'sgACC5', 'vmPFC2']
correlation_results_mdd = {}

for var in corr_variables:
    r, p_value = pearsonr(mdd_group['TEPSC'], mdd_group[var])
    correlation_results_mdd[var] = {'correlation_coefficient': r, 'p_value': p_value}

# Calculate correlations between TEPSC and other variables for HC group
correlation_results_hc = {}

for var in corr_variables:
    r, p_value = pearsonr(hc_group['TEPSC'], hc_group[var])
    correlation_results_hc[var] = {'correlation_coefficient': r, 'p_value': p_value}

# Perform partial correlation analysis controlling for covariates for MDD group
partial_corr_results_mdd = {}

for var in corr_variables:
    covariates = ['SUB_gender_1_F_0_M', 'SUB_Age', 'Medication_1_yes_0_no', 'Daw']
    X = sm.add_constant(mdd_group[[var] + covariates])
    partial_corr_model = sm.OLS(mdd_group['TEPSC'], X).fit()
    partial_corr_results_mdd[var] = {'coefficient': partial_corr_model.params[var],
                                     'p_value': partial_corr_model.pvalues[var],
                                     'effect_size': partial_corr_model.rsquared}

# Perform partial correlation analysis controlling for covariates for HC group
partial_corr_results_hc = {}

for var in corr_variables:
    covariates = ['SUB_gender_1_F_0_M', 'SUB_Age', 'Medication_1_yes_0_no', 'Daw']
    X = sm.add_constant(hc_group[[var] + covariates])
    partial_corr_model = sm.OLS(hc_group['TEPSC'], X).fit()
    partial_corr_results_hc[var] = {'coefficient': partial_corr_model.params[var],
                                     'p_value': partial_corr_model.pvalues[var],
                                     'effect_size': partial_corr_model.rsquared}

# Print the results for MDD group
for var in corr_variables:
    print(f"MDD Group: Correlation between TEPSC and {var}:")
    print(f"Pearson correlation coefficient: {correlation_results_mdd[var]['correlation_coefficient']}")
    print(f"Pearson correlation p-value: {correlation_results_mdd[var]['p_value']}")
    print(f"Partial correlation coefficient: {partial_corr_results_mdd[var]['coefficient']}")
    print(f"Partial correlation p-value: {partial_corr_results_mdd[var]['p_value']}")
    print(f"Partial correlation effect size (R-squared): {partial_corr_results_mdd[var]['effect_size']}")
    print("\n")

# Print the results for HC group
for var in corr_variables:
    print(f"HC Group: Correlation between TEPSC and {var}:")
    print(f"Pearson correlation coefficient: {correlation_results_hc[var]['correlation_coefficient']}")
    print(f"Pearson correlation p-value: {correlation_results_hc[var]['p_value']}")
    print(f"Partial correlation coefficient: {partial_corr_results_hc[var]['coefficient']}")
    print(f"Partial correlation p-value: {partial_corr_results_hc[var]['p_value']}")
    print(f"Partial correlation effect size (R-squared): {partial_corr_results_hc[var]['effect_size']}")
    print("\n")
# Out:
# MDD Group: Correlation between TEPSC and amyg:
# Pearson correlation coefficient: -0.1815381737160113
# Pearson correlation p-value: 0.26225088973055943
# Partial correlation coefficient: -8.83060532069456
# Partial correlation p-value: 0.36938692681291996
# Partial correlation effect size (R-squared): 0.06373891624940364
#
#
# MDD Group: Correlation between TEPSC and antPFC2:
# Pearson correlation coefficient: -0.257807445362508
# Pearson correlation p-value: 0.10825283352500949
# Partial correlation coefficient: -31.991529334128995
# Partial correlation p-value: 0.09352828764028781
# Partial correlation effect size (R-squared): 0.11816654576468144
#
#
# MDD Group: Correlation between TEPSC and dlPFC2:
# Pearson correlation coefficient: -0.0874848109254197
# Pearson correlation p-value: 0.5914138228007346
# Partial correlation coefficient: -6.12189376062593
# Partial correlation p-value: 0.6676589866730669
# Partial correlation effect size (R-squared): 0.04621328240695277
#
#
# MDD Group: Correlation between TEPSC and IFC:
# Pearson correlation coefficient: -0.20990357787398467
# Pearson correlation p-value: 0.19360486939506005
# Partial correlation coefficient: -18.43183146932403
# Partial correlation p-value: 0.2683135850364943
# Partial correlation effect size (R-squared): 0.07539125759130627
#
#
# MDD Group: Correlation between TEPSC and cg_3:
# Pearson correlation coefficient: -0.22939817831095854
# Pearson correlation p-value: 0.15447414159872477
# Partial correlation coefficient: -18.44543160550687
# Partial correlation p-value: 0.0726061701108736
# Partial correlation effect size (R-squared): 0.1289034036983211
#
#
# MDD Group: Correlation between TEPSC and cg_25_2:
# Pearson correlation coefficient: 0.02907454893444697
# Pearson correlation p-value: 0.8586521678438606
# Partial correlation coefficient: -0.07859925606618745
# Partial correlation p-value: 0.9942768631070165
# Partial correlation effect size (R-squared): 0.040952159469272664
#
#
# MDD Group: Correlation between TEPSC and dACC2:
# Pearson correlation coefficient: -0.33444021094065085
# Pearson correlation p-value: 0.03492086165989493
# Partial correlation coefficient: -25.667628048597717
# Partial correlation p-value: 0.04676900779328971
# Partial correlation effect size (R-squared): 0.14768799754611284
#
#
# MDD Group: Correlation between TEPSC and DCaud:
# Pearson correlation coefficient: -0.2576601155068243
# Pearson correlation p-value: 0.10846173300803133
# Partial correlation coefficient: -18.289516363559326
# Partial correlation p-value: 0.10121098102920882
# Partial correlation effect size (R-squared): 0.11483890789427864
#
#
# MDD Group: Correlation between TEPSC and dmPFC3:
# Pearson correlation coefficient: -0.2704866260397463
# Pearson correlation p-value: 0.0913936692430588
# Partial correlation coefficient: -25.60552272981091
# Partial correlation p-value: 0.07210613710800783
# Partial correlation effect size (R-squared): 0.12919751793076484
#
#
# MDD Group: Correlation between TEPSC and Hb_mni:
# Pearson correlation coefficient: -0.233105929914181
# Pearson correlation p-value: 0.14773737984895124
# Partial correlation coefficient: -13.049187592361672
# Partial correlation p-value: 0.1303512233133162
# Partial correlation effect size (R-squared): 0.10426202254380335
#
#
# MDD Group: Correlation between TEPSC and hipp_thr:
# Pearson correlation coefficient: -0.1303922294501706
# Pearson correlation p-value: 0.42257902127997127
# Partial correlation coefficient: -5.341230690269846
# Partial correlation p-value: 0.537241077985704
# Partial correlation effect size (R-squared): 0.051785801429094724
#
#
# MDD Group: Correlation between TEPSC and rl_accumbens:
# Pearson correlation coefficient: -0.2209686639612241
# Pearson correlation p-value: 0.17061838227268442
# Partial correlation coefficient: -17.220044005380657
# Partial correlation p-value: 0.1062249463645934
# Partial correlation effect size (R-squared): 0.11280655535701922
#
#
# MDD Group: Correlation between TEPSC and sgACC5:
# Pearson correlation coefficient: -0.1684964544342381
# Pearson correlation p-value: 0.29865262778376367
# Partial correlation coefficient: -18.348308722466122
# Partial correlation p-value: 0.17696298639159624
# Partial correlation effect size (R-squared): 0.09173523411727424
#
#
# MDD Group: Correlation between TEPSC and vmPFC2:
# Pearson correlation coefficient: -0.3224016764717309
# Pearson correlation p-value: 0.04246603227012634
# Partial correlation coefficient: -25.566293854902653
# Partial correlation p-value: 0.025746238502772103
# Partial correlation effect size (R-squared): 0.17321953948308855
#
#
# HC Group: Correlation between TEPSC and amyg:
# Pearson correlation coefficient: -0.22247795585210103
# Pearson correlation p-value: 0.17942434116266523
# Partial correlation coefficient: -17.332513374568755
# Partial correlation p-value: 0.0479528474952981
# Partial correlation effect size (R-squared): 0.2110301689601486
#
#
# HC Group: Correlation between TEPSC and antPFC2:
# Pearson correlation coefficient: -0.029105042442441692
# Pearson correlation p-value: 0.8622908647746854
# Partial correlation coefficient: -3.745026665537255
# Partial correlation p-value: 0.8044096252137387
# Partial correlation effect size (R-squared): 0.11182694399687032
#
#
# HC Group: Correlation between TEPSC and dlPFC2:
# Pearson correlation coefficient: -0.003483812343392266
# Pearson correlation p-value: 0.9834384625618862
# Partial correlation coefficient: -2.539056807725661
# Partial correlation p-value: 0.8776374138275213
# Partial correlation effect size (R-squared): 0.11079831066952517
#
#
# HC Group: Correlation between TEPSC and IFC:
# Pearson correlation coefficient: -0.34421217155137884
# Pearson correlation p-value: 0.03433374084959067
# Partial correlation coefficient: -42.45142392663112
# Partial correlation p-value: 0.0166975259600781
# Partial correlation effect size (R-squared): 0.25389138440964143
#
#
# HC Group: Correlation between TEPSC and cg_3:
# Pearson correlation coefficient: -0.033660977068614435
# Pearson correlation p-value: 0.8409915411178426
# Partial correlation coefficient: -2.314190044520103
# Partial correlation p-value: 0.8051045993756858
# Partial correlation effect size (R-squared): 0.11181481202412602
#
#
# HC Group: Correlation between TEPSC and cg_25_2:
# Pearson correlation coefficient: -0.20345954098213126
# Pearson correlation p-value: 0.22050886433989408
# Partial correlation coefficient: -15.252076201159545
# Partial correlation p-value: 0.18698053908852455
# Partial correlation effect size (R-squared): 0.15656192973856153
#
#
# HC Group: Correlation between TEPSC and dACC2:
# Pearson correlation coefficient: 0.010425458510173836
# Pearson correlation p-value: 0.9504659885571209
# Partial correlation coefficient: -1.2814579337728311
# Partial correlation p-value: 0.8776668604879292
# Partial correlation effect size (R-squared): 0.11079799610763319
#
#
# HC Group: Correlation between TEPSC and DCaud:
# Pearson correlation coefficient: -0.0034827722892895848
# Pearson correlation p-value: 0.9834434061481403
# Partial correlation coefficient: 1.4804066895986772
# Partial correlation p-value: 0.8546696737079101
# Partial correlation effect size (R-squared): 0.1110675617390886
#
#
# HC Group: Correlation between TEPSC and dmPFC3:
# Pearson correlation coefficient: -0.24111554467544252
# Pearson correlation p-value: 0.14475799142686363
# Partial correlation coefficient: -23.841735878994143
# Partial correlation p-value: 0.09832101170342133
# Partial correlation effect size (R-squared): 0.1818928371043682
#
#
# HC Group: Correlation between TEPSC and Hb_mni:
# Pearson correlation coefficient: 0.16553402125716718
# Pearson correlation p-value: 0.32060920666223325
# Partial correlation coefficient: 4.209763164704929
# Partial correlation p-value: 0.411078310159639
# Partial correlation effect size (R-squared): 0.12845609134293468
#
#
# HC Group: Correlation between TEPSC and hipp_thr:
# Pearson correlation coefficient: -0.21507853877513208
# Pearson correlation p-value: 0.19470627002169538
# Partial correlation coefficient: -18.804823136301906
# Partial correlation p-value: 0.06591467151849863
# Partial correlation effect size (R-squared): 0.1980710179348466
#
#
# HC Group: Correlation between TEPSC and rl_accumbens:
# Pearson correlation coefficient: 0.004128414030320518
# Pearson correlation p-value: 0.9803746655167035
# Partial correlation coefficient: -0.268589220786815
# Partial correlation p-value: 0.9686140611485189
# Partial correlation effect size (R-squared): 0.1101919586892588
#
#
# HC Group: Correlation between TEPSC and sgACC5:
# Pearson correlation coefficient: -0.039081394637117156
# Pearson correlation p-value: 0.8157963298721558
# Partial correlation coefficient: -3.6218004181995553
# Partial correlation p-value: 0.7731003191325179
# Partial correlation effect size (R-squared): 0.11242247966833452
#
#
# HC Group: Correlation between TEPSC and vmPFC2:
# Pearson correlation coefficient: -0.001919098216086921
# Pearson correlation p-value: 0.9908764490110378
# Partial correlation coefficient: -1.717132283661698
# Partial correlation p-value: 0.8548725553581351
# Partial correlation effect size (R-squared): 0.111064973088427

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats import pearsonr

# Split data into MDD group and HC group
mdd_group = df[df['subj'].astype(str).str.startswith('4')]
hc_group = df[df['subj'].astype(str).str.startswith('5')]

# Calculate correlations between SHAPS and other variables for MDD group
corr_variables = ['amyg', 'antPFC2', 'dlPFC2', 'IFC', 'cg_3', 'cg_25_2', 'dACC2', 'DCaud', 'dmPFC3', 'Hb_mni', 'hipp_thr', 'rl_accumbens', 'sgACC5', 'vmPFC2']
correlation_results_mdd = {}

for var in corr_variables:
    r, p_value = pearsonr(mdd_group['SHAPS'], mdd_group[var])
    correlation_results_mdd[var] = {'correlation_coefficient': r, 'p_value': p_value}

# Calculate correlations between SHAPS and other variables for HC group
correlation_results_hc = {}

for var in corr_variables:
    r, p_value = pearsonr(hc_group['SHAPS'], hc_group[var])
    correlation_results_hc[var] = {'correlation_coefficient': r, 'p_value': p_value}

# Perform partial correlation analysis controlling for covariates for MDD group
partial_corr_results_mdd = {}

for var in corr_variables:
    covariates = ['SUB_gender_1_F_0_M', 'SUB_Age', 'Medication_1_yes_0_no', 'Daw']
    X = sm.add_constant(mdd_group[[var] + covariates])
    partial_corr_model = sm.OLS(mdd_group['SHAPS'], X).fit()
    partial_corr_results_mdd[var] = {'coefficient': partial_corr_model.params[var],
                                     'p_value': partial_corr_model.pvalues[var],
                                     'effect_size': partial_corr_model.rsquared}

# Perform partial correlation analysis controlling for covariates for HC group
partial_corr_results_hc = {}

for var in corr_variables:
    covariates = ['SUB_gender_1_F_0_M', 'SUB_Age', 'Medication_1_yes_0_no', 'Daw']
    X = sm.add_constant(hc_group[[var] + covariates])
    partial_corr_model = sm.OLS(hc_group['SHAPS'], X).fit()
    partial_corr_results_hc[var] = {'coefficient': partial_corr_model.params[var],
                                     'p_value': partial_corr_model.pvalues[var],
                                     'effect_size': partial_corr_model.rsquared}

# Print the results for MDD group
for var in corr_variables:
    print(f"MDD Group: Correlation between SHAPS and {var}:")
    print(f"Pearson correlation coefficient: {correlation_results_mdd[var]['correlation_coefficient']}")
    print(f"Pearson correlation p-value: {correlation_results_mdd[var]['p_value']}")
    print(f"Partial correlation coefficient: {partial_corr_results_mdd[var]['coefficient']}")
    print(f"Partial correlation p-value: {partial_corr_results_mdd[var]['p_value']}")
    print(f"Partial correlation effect size (R-squared): {partial_corr_results_mdd[var]['effect_size']}")
    print("\n")

# Print the results for HC group
for var in corr_variables:
    print(f"HC Group: Correlation between SHAPS and {var}:")
    print(f"Pearson correlation coefficient: {correlation_results_hc[var]['correlation_coefficient']}")
    print(f"Pearson correlation p-value: {correlation_results_hc[var]['p_value']}")
    print(f"Partial correlation coefficient: {partial_corr_results_hc[var]['coefficient']}")
    print(f"Partial correlation p-value: {partial_corr_results_hc[var]['p_value']}")
    print(f"Partial correlation effect size (R-squared): {partial_corr_results_hc[var]['effect_size']}")
    print("\n")
# Out:
# MDD Group: Correlation between SHAPS and amyg:
# Pearson correlation coefficient: 0.27718433258480285
# Pearson correlation p-value: 0.0833467955649003
# Partial correlation coefficient: 12.807401379206667
# Partial correlation p-value: 0.13633701783757798
# Partial correlation effect size (R-squared): 0.16264644875017065
#
#
# MDD Group: Correlation between SHAPS and antPFC2:
# Pearson correlation coefficient: 0.15496596849539412
# Pearson correlation p-value: 0.3396804918508245
# Partial correlation coefficient: 23.52404051484812
# Partial correlation p-value: 0.16540106938529214
# Partial correlation effect size (R-squared): 0.15525013579106894
#
#
# MDD Group: Correlation between SHAPS and dlPFC2:
# Pearson correlation coefficient: -0.0999696660442558
# Pearson correlation p-value: 0.5393770779163085
# Partial correlation coefficient: -7.963672366542134
# Partial correlation p-value: 0.5264542630580635
# Partial correlation effect size (R-squared): 0.11596952602016897
#
#
# MDD Group: Correlation between SHAPS and IFC:
# Pearson correlation coefficient: 0.23476166202183932
# Pearson correlation p-value: 0.14479963675379742
# Partial correlation coefficient: 16.452812322365364
# Partial correlation p-value: 0.26314101364712317
# Partial correlation effect size (R-squared): 0.13813800600940773
#
#
# MDD Group: Correlation between SHAPS and cg_3:
# Pearson correlation coefficient: 0.1842827399464572
# Pearson correlation p-value: 0.2549825197580659
# Partial correlation coefficient: 14.454645929903316
# Partial correlation p-value: 0.11306000020291782
# Partial correlation effect size (R-squared): 0.1699137681232712
#
#
# MDD Group: Correlation between SHAPS and cg_25_2:
# Pearson correlation coefficient: 0.1348532883956635
# Pearson correlation p-value: 0.4067414964945638
# Partial correlation coefficient: 10.42411123549956
# Partial correlation p-value: 0.2771976696366653
# Partial correlation effect size (R-squared): 0.13630005048075278
#
#
# MDD Group: Correlation between SHAPS and dACC2:
# Pearson correlation coefficient: 0.07455758955938117
# Pearson correlation p-value: 0.6475069797740594
# Partial correlation coefficient: 8.953842290614954
# Partial correlation p-value: 0.4436510481074444
# Partial correlation effect size (R-squared): 0.12085279684413208
#
#
# MDD Group: Correlation between SHAPS and DCaud:
# Pearson correlation coefficient: 0.0366054488377676
# Pearson correlation p-value: 0.8225651496991564
# Partial correlation coefficient: 3.1126557385881224
# Partial correlation p-value: 0.7567053392606445
# Partial correlation effect size (R-squared): 0.10787857526600553
#
#
# MDD Group: Correlation between SHAPS and dmPFC3:
# Pearson correlation coefficient: 0.30127705928726756
# Pearson correlation p-value: 0.05886772299886031
# Partial correlation coefficient: 31.159401868502734
# Partial correlation p-value: 0.011196520306941234
# Partial correlation effect size (R-squared): 0.2616050729396959
#
#
# MDD Group: Correlation between SHAPS and Hb_mni:
# Pearson correlation coefficient: -0.10476667640418404
# Pearson correlation p-value: 0.5199867875593521
# Partial correlation coefficient: -3.687749773396071
# Partial correlation p-value: 0.6335923983594245
# Partial correlation effect size (R-squared): 0.11136624931646166
#
#
# MDD Group: Correlation between SHAPS and hipp_thr:
# Pearson correlation coefficient: 0.25211145914852845
# Pearson correlation p-value: 0.11655416206185056
# Partial correlation coefficient: 10.788071997607538
# Partial correlation p-value: 0.15314633570718486
# Partial correlation effect size (R-squared): 0.15818172520052165
#
#
# MDD Group: Correlation between SHAPS and rl_accumbens:
# Pearson correlation coefficient: 0.09382593804604462
# Pearson correlation p-value: 0.5647076690560352
# Partial correlation coefficient: 8.5059102933827
# Partial correlation p-value: 0.37272722916575096
# Partial correlation effect size (R-squared): 0.1262865752447373
#
#
# MDD Group: Correlation between SHAPS and sgACC5:
# Pearson correlation coefficient: 0.10249536550195601
# Pearson correlation p-value: 0.529124602240633
# Partial correlation coefficient: 12.083789685192425
# Partial correlation p-value: 0.31699282649374144
# Partial correlation effect size (R-squared): 0.1316615663368811
#
#
# MDD Group: Correlation between SHAPS and vmPFC2:
# Pearson correlation coefficient: 0.14248291833516874
# Pearson correlation p-value: 0.38045795336408783
# Partial correlation coefficient: 11.387931489850796
# Partial correlation p-value: 0.27403102076791663
# Partial correlation effect size (R-squared): 0.1367041053487562
#
#
# HC Group: Correlation between SHAPS and amyg:
# Pearson correlation coefficient: 0.2980805466126484
# Pearson correlation p-value: 0.06911302781657547
# Partial correlation coefficient: 14.453387250281033
# Partial correlation p-value: 0.10329264420800517
# Partial correlation effect size (R-squared): 0.15604575991982916
#
#
# HC Group: Correlation between SHAPS and antPFC2:
# Pearson correlation coefficient: -0.27027572500642366
# Pearson correlation p-value: 0.10076821725981099
# Partial correlation coefficient: -20.473238992673902
# Partial correlation p-value: 0.17100289592418383
# Partial correlation effect size (R-squared): 0.13555664260822986
#
#
# HC Group: Correlation between SHAPS and dlPFC2:
# Pearson correlation coefficient: -0.00273386235499953
# Pearson correlation p-value: 0.9870032723869817
# Partial correlation coefficient: -0.17377550362854777
# Partial correlation p-value: 0.9916171764499582
# Partial correlation effect size (R-squared): 0.0842560234965748
#
#
# HC Group: Correlation between SHAPS and IFC:
# Pearson correlation coefficient: 0.15086956194573048
# Pearson correlation p-value: 0.36591831112276796
# Partial correlation coefficient: 18.641329711392892
# Partial correlation p-value: 0.31184983301161384
# Partial correlation effect size (R-squared): 0.11261967209777601
#
#
# HC Group: Correlation between SHAPS and cg_3:
# Pearson correlation coefficient: -0.08175144516120636
# Pearson correlation p-value: 0.6255970458287339
# Partial correlation coefficient: -8.24510720803729
# Partial correlation p-value: 0.3780271525863721
# Partial correlation effect size (R-squared): 0.10588645727638768
#
#
# HC Group: Correlation between SHAPS and cg_25_2:
# Pearson correlation coefficient: -0.012360233264512775
# Pearson correlation p-value: 0.9412880418884728
# Partial correlation coefficient: -2.373956400494089
# Partial correlation p-value: 0.8397878347013785
# Partial correlation effect size (R-squared): 0.0854036569244162
#
#
# HC Group: Correlation between SHAPS and dACC2:
# Pearson correlation coefficient: -0.2835116898125597
# Pearson correlation p-value: 0.08454668730541463
# Partial correlation coefficient: -14.3061485487379
# Partial correlation p-value: 0.07939722919674233
# Partial correlation effect size (R-squared): 0.16696146751446828
#
#
# HC Group: Correlation between SHAPS and DCaud:
# Pearson correlation coefficient: -0.2267431946618878
# Pearson correlation p-value: 0.1710136572043653
# Partial correlation coefficient: -10.132538467636072
# Partial correlation p-value: 0.20575403461956923
# Partial correlation effect size (R-squared): 0.12826456110016649
#
#
# HC Group: Correlation between SHAPS and dmPFC3:
# Pearson correlation coefficient: -0.2530898385841487
# Pearson correlation p-value: 0.12524730549777713
# Partial correlation coefficient: -20.263320346312312
# Partial correlation p-value: 0.1637336920681192
# Partial correlation effect size (R-squared): 0.1372905234779328
#
#
# HC Group: Correlation between SHAPS and Hb_mni:
# Pearson correlation coefficient: 0.0017490066851847908
# Pearson correlation p-value: 0.991685048761661
# Partial correlation coefficient: -0.2398917123219536
# Partial correlation p-value: 0.9629353677543808
# Partial correlation effect size (R-squared): 0.08431375198166302
#
#
# HC Group: Correlation between SHAPS and hipp_thr:
# Pearson correlation coefficient: 0.18221417382276694
# Pearson correlation p-value: 0.27355188284740173
# Partial correlation coefficient: 8.465138338109265
# Partial correlation p-value: 0.4187748718282365
# Partial correlation effect size (R-squared): 0.10248690600367172
#
#
# HC Group: Correlation between SHAPS and rl_accumbens:
# Pearson correlation coefficient: -0.19878873966082927
# Pearson correlation p-value: 0.23151447969420938
# Partial correlation coefficient: -8.294707296618895
# Partial correlation p-value: 0.22026680169649368
# Partial correlation effect size (R-squared): 0.12562128893475832
#
#
# HC Group: Correlation between SHAPS and sgACC5:
# Pearson correlation coefficient: -0.10759758900521753
# Pearson correlation p-value: 0.5202305111266606
# Partial correlation coefficient: -12.498834530216769
# Partial correlation p-value: 0.3176681573498825
# Partial correlation effect size (R-squared): 0.11195601230019114
#
#
# HC Group: Correlation between SHAPS and vmPFC2:
# Pearson correlation coefficient: -0.29394251240947356
# Pearson correlation p-value: 0.07325167855770404
# Partial correlation coefficient: -16.137323130834105
# Partial correlation p-value: 0.07933488763382836
# Partial correlation effect size (R-squared): 0.16699419785271075
